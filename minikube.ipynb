# %%
import pandas as pd
import dbt

# %%
r1 = pd.read_csv("/Users/mac/Downloads/data_sample/r1.csv",  delimiter=',', encoding='utf-8', error_bad_lines = False)
r1
# Out:
# /var/folders/4h/4pn50dts6_371n4m5q689q8m0000gn/T/ipykernel_64709/762981667.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   r1 = pd.read_csv("/Users/mac/Downloads/data_sample/r1.csv",  delimiter=',', encoding='utf-8', error_bad_lines = False)
# Skipping line 90: expected 32 fields, saw 33
# Skipping line 370: expected 32 fields, saw 33
#        id     job_title                                            descr50  \
# 0    1367  ACC MAN       Account Management Staff                      ...
# 1    1247  ADM ASS SR    Finance & Administration Staff                ...
# 2    1533  ADMIN         Thư ký Marketing                             ...
# 3    1504  ASM           Giám đốc bán hàng khu vực                ...
# 4    1559  ASM (GĐBH)    GĐ bán hàng kênh Ecommerce                  ...
# ..    ...           ...                                                ...
# ...

# %%
r1.columns
# Out:
# Index(['id', 'job_title', 'descr50', 'job_level', 'job_grp', 'vert_grp',
#        'notes', 'del_doc_path', 'del_doc_name', 'beroep_cd', 'code_fnc',
#        'schaalsrt', 'schaalcode', 'kmrateint', 'productiv', 'prodpct',
#        'xdefratelv', 'inttar', 'exttar', 'timestamp', 'docid', 'roleid',
#        'rolelevel', 'scalemin', 'scalemax', 'wkcp_risk', 'division',
#        'syscreated', 'syscreator', 'sysmodified', 'sysmodifier', 'sysguid'],
#       dtype='object')

# %%
r1.to_csv('/Users/mac/Downloads/data_sample/test1.csv', index=False)

# %%
r3 = pd.read_csv("/Users/mac/Downloads/data_sample/r3.csv",  delimiter=',', encoding='utf-8', error_bad_lines = False)
r3
# Out:
# /var/folders/4h/4pn50dts6_371n4m5q689q8m0000gn/T/ipykernel_64709/3933880576.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   r3 = pd.read_csv("/Users/mac/Downloads/data_sample/r3.csv",  delimiter=',', encoding='utf-8', error_bad_lines = False)
#     id         loc                                            descr50  \
# 0    1  0450NX      VPTĐ Sunhouse 50 Nguyễn Xiển                ...
# 1    3  04KM21TL    Km 21 Đại Lộ Thăng long                     ...
# 2    8  04KM22TL    KM22 Đại Lộ Thăng Long                      ...
# 3    2  04KM8       KM8 Đại Lộ Thăng Long                       ...
# 4    9  04RICHYT12  Tầng 12, tòa nhà RichyTower - 35 Mạc Thái...
# 5    5  04VINX9     Tầng 12 Tòa nhà Vinaconex 9                 ...
# 6    6  04VINX9T15  Tầng 15 Tòa nhà Vinaconex 9                 ...
# 7    4  051ĐBP      Điện biên Phủ-ĐN                            ...
# ...

# %%
r3.columns
# Out:
# Index(['id', 'loc', 'descr50', 'street_0', 'street_1', 'addr_no', 'addr_suf',
#        'postcode', 'city', 'country', 'telnr', 'faxnr', 'xaddress2',
#        'statecode', 'weekendstart', 'weekendend', 'division', 'syscreated',
#        'syscreator', 'sysmodified', 'sysmodifier', 'sysguid', 'timestamp'],
#       dtype='object')

# %%
print(r3['id'].dtype)
# Out:
# int64

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://myuser:mypassword@192.168.59.101:31137/mydatabase')

# %%
engine1 = create_engine('postgresql://myuser2:mypassword2@192.168.59.101:32133/mydatabase2')

# %%
try:
    # Thực hiện truy vấn SQL đơn giản để kiểm tra kết nối
    result = engine1.execute("SELECT 1")
    
    # In ra kết quả của truy vấn
    print(result.fetchone())
    
    # Đóng kết nối
    result.close()
    
    print("Kết nối thành công!")
except Exception as e:
    print("Lỗi khi thực hiện truy vấn:", e)
# Out:
# (1,)
# Kết nối thành công!

# %%
from sqlalchemy import create_engine, MetaData

# %%
meta = MetaData()

# Gắn kết nối engine với MetaData
meta.reflect(bind=engine)

# Lấy danh sách các bảng
tables = meta.tables.keys()
print("Danh sách các bảng:")
for table in tables:
    print(table)
# Out:
# Danh sách các bảng:

# %%
tables
# Out:
# dict_keys(['location', 'table1', 'table2'])

# %%
r3.to_sql('table3', engine1, index=False)
# Out:
# 13

# %%
r1.to_sql('table1', engine, index=False)
# Out:
# 519

# %%
r2 = pd.read_csv("/Users/mac/Downloads/data_sample/r2.csv",  delimiter=',', encoding='utf-8', error_bad_lines = False)
r2

# %%
r2.to_sql('table2', engine, index=False)

# %%
df = ref("my_postgres_connection")

# %%
from sqlalchemy import create_engine, MetaData, Table, select
# Tạo đối tượng MetaData
metadata = MetaData()

# Liên kết đối tượng MetaData với đối tượng kết nối (engine)
metadata.reflect(bind=engine)
table = Table('table1', metadata, autoload_with=engine)

# %%
select([table])
result = engine.execute(select([table]))

# %%
for row in result:
    print(row)
# Out:
# ('1367', 'ACC MAN     ', 'Account Management Staff                          ', 14.0, 'SM        ', 'ACCMAN    ', None, None, 'GR1                                                                                                                             ', None, None, None, None, 0.0, 0.0, 0.0, None, 0.0, 0.0, None, None, None, None, 0.0, 0.0, None, 101.0, '2000-10-18 16:15:33.780', 0.0, '2000-10-18 16:15:33.780', 0.0, '1109E942-629A-416B-8BF4-6EE08A1BAE23')
# ('1247', 'ADM ASS SR  ', 'Finance & Administration Staff                    ', 12.0, 'FA        ', 'FA        ', None, None, None, None, None, None, None, 0.0, 0.0, 0.0, None, 0.0, 0.0, None, None, None, None, 0.0, 0.0, None, 101.0, '2000-10-18 16:15:33.780', 0.0, '2000-10-18 16:15:33.780', 0.0, 'C7458956-37BB-4734-9672-0D13B553EC38')
# ...

# %%
import dbt
from dbt.adapters.factory import get_adapter

# %%
connection = adapter.connections.create_connection(
    'dbt_postgres_1',
    host='192.168.59.100',
    user='myuser',
    password='mypassword',
    database='mydatabase'
)
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3378, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/4h/4pn50dts6_371n4m5q689q8m0000gn/T/ipykernel_14273/4257168815.py", line 1, in <module>
#     connection = dbt.adapter.connections.create_connection(
# AttributeError: module 'dbt' has no attribute 'adapter'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 1997, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "/usr/local/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1112, in structured_traceback
#     return FormattedTB.structured_traceback(
# ...
